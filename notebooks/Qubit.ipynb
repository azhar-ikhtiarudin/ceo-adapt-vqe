# %%
import sys
sys.path.append('/home/azhar04/project/1. dev/quantum-dev/ceo-adapt-vqe')
print(sys.executable)
# Out:
# /home/azhar04/anaconda3/envs/adapt-vqe-dev/bin/python

# %%
from adaptvqe.molecules import create_h2, create_h3, create_h4
from adaptvqe.pools import QE
from adaptvqe.algorithms.adapt_vqe import LinAlgAdapt

r = 1.5
molecule = create_h4(r)
pool = QE(molecule)

my_adapt = LinAlgAdapt(
    pool=pool,
    molecule=molecule,
    max_adapt_iter=5,
    recycle_hessian=True,
    tetris=True,
    verbose=True,
    threshold=0.1,
)

my_adapt.run()
data = my_adapt.data

# Access the final ansatz indices and coefficients
print("Evolution of ansatz indices: ", data.evolution.indices)
print(
    "Final operators in the ansatz: ",
    [pool.get_op(index) for index in data.result.ansatz.indices],
)
print("Evolution of ansatz coefficients: ", data.evolution.coefficients)

# Access the number of function evaluations, gradient evaluations, optimizer iterations for each ADAPT-VQE iteration
print("Function evaluations throughout the iterations:", data.evolution.nfevs)
print("Gradient evaluations throughout the iterations:", data.evolution.ngevs)
print("Optimizer iterations throughout the iterations:", data.evolution.nits)

# Create the circuit implementing the final ansatz
qc = pool.get_circuit(data.result.ansatz.indices, data.result.ansatz.coefficients)
print("Final ansatz circuit:\n", qc)

# Access the number of CNOTs and CNOT depth at each iteration
print("Evolution of ansatz CNOT counts: ", data.acc_cnot_counts(pool))
print("Evolution of ansatz CNOT depths: ", data.acc_cnot_depths(pool))
# Out:
# linalg_adapt prepared with the following settings:
# > Pool: QE
# > Molecule: H4 (interatomic distance 1.5Å)
# > Orbital Optimization: False
# > Selection method: gradient
# > Convergence criterion: total_g_norm
# > Recycling Hessian: True
# > Tetris: True (progressive optimization: False)
# > Convergence threshold (gradient norm):  0.1
# > Maximum number of iterations:  5
# > candidates per iteration:  1
#
# Initial energy: -1.8291374123526871
#
# *** ADAPT-VQE Iteration 1 ***
#
# Creating list of up to 90 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 7.059732494624216e-06
# Operator 4: -7.059732494589521e-06
# Operator 7: 4.203156611690129e-06
# Operator 9: -4.203156611717884e-06
# Operator 22: 0.23023442946234082
# Operator 28: 0.21992018626401855
# Operator 34: 0.06698963620326329
# Operator 41: -0.22713884882669277
# Operator 43: 0.16014921262342952
# Operator 57: 0.16014921262342952
# Operator 59: -0.22713884882669277
# Operator 65: 0.06698963620326327
# Operator 72: 0.2814232751400025
# Operator 78: 0.23558951465233474
# Total gradient norm: 0.6320831723702518
# Operators under consideration (14):
# [72, 78, 22, 41, 59, 28, 43, 57, 34, 65, 1, 4, 9, 7]
# Corresponding gradients (ordered by magnitude):
# [0.2814232751400025, 0.23558951465233474, 0.23023442946234082, -0.22713884882669277, -0.22713884882669277, 0.21992018626401855, 0.16014921262342952, 0.16014921262342952, 0.06698963620326329, 0.06698963620326327, 7.059732494624216e-06, -7.059732494589521e-06, -4.203156611717884e-06, 4.203156611690129e-06]
# Operator(s) added to ansatz: [72]
#
# Screening operators with disjoint supports...
# 1 viable candidates: [28]
# Operator(s) added to ansatz: [72, 28]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -1.8291374123526871
# Optimizing energy with indices [72, 28]...
# Starting point: [0.0, 0.0]
# Optimization terminated successfully.
#          Current function value: -1.886048
#          Iterations: 7
#          Function evaluations: 8
#          Gradient evaluations: 8
#
# Current energy: -1.886047737368181
# (change of -0.05691032501549387)
# Current ansatz: [72, 28]
#
# *** ADAPT-VQE Iteration 2 ***
#
# Creating list of up to 90 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 0.05331552917935413
# Operator 4: -0.053315529179354094
# Operator 7: 0.05559081822085891
# Operator 9: -0.055590818220858935
# Operator 12: -0.01799916480156217
# Operator 16: 0.004822550120739276
# Operator 20: -0.004822550120739274
# Operator 22: 0.08590450580510815
# Operator 31: -0.013253073422174752
# Operator 34: 0.11967958621644761
# Operator 36: -0.04275532432148547
# Operator 37: 0.06795584953666776
# Operator 41: -0.32272850998501446
# Operator 43: 0.20304892376856692
# Operator 44: -0.025200525215182304
# Operator 49: -0.005041582074458318
# Operator 52: 0.013253073422174742
# Operator 57: 0.20304892376856692
# Operator 58: -0.025200525215182294
# Operator 59: -0.32272850998501446
# Operator 63: 0.06795584953666776
# Operator 65: 0.11967958621644761
# Operator 67: -0.04275532432148547
# Operator 70: 0.005041582074458315
# Operator 78: 0.08677620382569723
# Operator 81: -0.013960930266969273
# Operator 85: 0.013960930266969264
# Operator 88: -0.018361627500614403
# Total gradient norm: 0.6015386254374062
# Operators under consideration (28):
# [41, 59, 43, 57, 34, 65, 78, 22, 37, 63, 9, 7, 1, 4, 36, 67, 44, 58, 88, 12, 81, 85, 31, 52, 49, 70, 16, 20]
# Corresponding gradients (ordered by magnitude):
# [-0.32272850998501446, -0.32272850998501446, 0.20304892376856692, 0.20304892376856692, 0.11967958621644761, 0.11967958621644761, 0.08677620382569723, 0.08590450580510815, 0.06795584953666776, 0.06795584953666776, -0.055590818220858935, 0.05559081822085891, 0.05331552917935413, -0.053315529179354094, -0.04275532432148547, -0.04275532432148547, -0.025200525215182304, -0.025200525215182294, -0.018361627500614403, -0.01799916480156217, -0.013960930266969273, 0.013960930266969264, -0.013253073422174752, 0.013253073422174742, -0.005041582074458318, 0.005041582074458315, 0.004822550120739276, -0.004822550120739274]
# Operator(s) added to ansatz: [41]
#
# Screening operators with disjoint supports...
# 3 viable candidates: [59, 7, 4]
# Operator(s) added to ansatz: [41, 59]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -1.886047737368181
# Optimizing energy with indices [72, 28, 41, 59]...
# Starting point: [-0.30688337459482085, -0.11344101184957128, 0.0, 0.0]
# Optimization terminated successfully.
#          Current function value: -1.973908
#          Iterations: 8
#          Function evaluations: 9
#          Gradient evaluations: 9
#
# Current energy: -1.9739084777458447
# (change of -0.08786074037766367)
# Current ansatz: [72, 28, 41, 59]
#
# *** ADAPT-VQE Iteration 3 ***
#
# Creating list of up to 90 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 0.039690604150864145
# Operator 4: -0.03969060415086404
# Operator 7: 0.0410791665337989
# Operator 9: -0.04107916653379903
# Operator 12: -0.022222122109895905
# Operator 16: -0.008173748128302771
# Operator 20: 0.008173748128302814
# Operator 22: 0.07617070418349588
# Operator 31: -0.01377364346889497
# Operator 34: 0.0313785989273152
# Operator 35: -0.00011541727730322643
# Operator 36: -0.019498132600622872
# Operator 37: 0.010872497444480343
# Operator 43: 0.06700654323251024
# Operator 44: -0.009130811010255329
# Operator 49: 0.009261010691270291
# Operator 52: 0.013773643468894921
# Operator 57: 0.06700654323251021
# Operator 58: -0.00913081101025532
# Operator 63: 0.010872497444480232
# Operator 65: 0.031378598927315184
# Operator 66: -0.0001154172773031386
# Operator 67: -0.019498132600622862
# Operator 70: -0.009261010691270343
# Operator 78: 0.07566546479599925
# Operator 81: -0.013813968741386348
# Operator 85: 0.013813968741386304
# Operator 88: -0.0219604548969477
# Total gradient norm: 0.17946523715076101
# Operators under consideration (28):
# [22, 78, 43, 57, 9, 7, 1, 4, 34, 65, 12, 88, 36, 67, 81, 85, 31, 52, 37, 63, 70, 49, 44, 58, 20, 16, 35, 66]
# Corresponding gradients (ordered by magnitude):
# [0.07617070418349588, 0.07566546479599925, 0.06700654323251024, 0.06700654323251021, -0.04107916653379903, 0.0410791665337989, 0.039690604150864145, -0.03969060415086404, 0.0313785989273152, 0.031378598927315184, -0.022222122109895905, -0.0219604548969477, -0.019498132600622872, -0.019498132600622862, -0.013813968741386348, 0.013813968741386304, -0.01377364346889497, 0.013773643468894921, 0.010872497444480343, 0.010872497444480232, -0.009261010691270343, 0.009261010691270291, -0.009130811010255329, -0.00913081101025532, 0.008173748128302814, -0.008173748128302771, -0.00011541727730322643, -0.0001154172773031386]
# Operator(s) added to ansatz: [22]
#
# Screening operators with disjoint supports...
# 3 viable candidates: [78, 9, 7]
# Operator(s) added to ansatz: [22, 78]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -1.9739084777458447
# Optimizing energy with indices [72, 28, 41, 59, 22, 78]...
# Starting point: [-0.37342137573909673, -0.15690533179199273, 0.2718258895584216, 0.27182588955842196, 0.0, 0.0]
# Optimization terminated successfully.
#          Current function value: -1.980204
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
#
# Current energy: -1.9802044582444092
# (change of -0.006295980498564502)
# Current ansatz: [72, 28, 41, 59, 22, 78]
#
# *** ADAPT-VQE Iteration 4 ***
#
# Creating list of up to 90 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 0.022529862103228857
# Operator 4: -0.022529862103228732
# Operator 7: 0.02470248769901621
# Operator 9: -0.024702487699016312
# Operator 12: -0.0013604837351524346
# Operator 16: -0.008681290294920317
# Operator 20: 0.008681290294920348
# Operator 31: -0.008290016156243921
# Operator 34: 0.0050395931198872965
# Operator 35: 0.00042960747231488277
# Operator 36: -0.02369220688346575
# Operator 37: 0.006589049624988855
# Operator 38: -0.0015447364828089483
# Operator 42: -8.450422373274045e-05
# Operator 43: 0.09212371887378963
# Operator 44: -0.0012960731966154965
# Operator 49: 0.009580297866984612
# Operator 52: 0.00829001615624389
# Operator 57: 0.09212371887378962
# Operator 58: -0.0012960731966154947
# Operator 60: -8.450422373274219e-05
# Operator 63: 0.006589049624988887
# Operator 64: -0.00154473648280895
# Operator 65: 0.005039593119887269
# Operator 66: 0.0004296074723148806
# Operator 67: -0.02369220688346574
# Operator 70: -0.009580297866984644
# Operator 81: -0.00865180824389332
# Operator 85: 0.008651808243893291
# Operator 88: -0.002241803998302906
# Total gradient norm: 0.14528001918813493
# Operators under consideration (30):
# [43, 57, 9, 7, 36, 67, 1, 4, 70, 49, 20, 16, 81, 85, 31, 52, 63, 37, 34, 65, 88, 64, 38, 12, 44, 58, 35, 66, 60, 42]
# Corresponding gradients (ordered by magnitude):
# [0.09212371887378963, 0.09212371887378962, -0.024702487699016312, 0.02470248769901621, -0.02369220688346575, -0.02369220688346574, 0.022529862103228857, -0.022529862103228732, -0.009580297866984644, 0.009580297866984612, 0.008681290294920348, -0.008681290294920317, -0.00865180824389332, 0.008651808243893291, -0.008290016156243921, 0.00829001615624389, 0.006589049624988887, 0.006589049624988855, 0.0050395931198872965, 0.005039593119887269, -0.002241803998302906, -0.00154473648280895, -0.0015447364828089483, -0.0013604837351524346, -0.0012960731966154965, -0.0012960731966154947, 0.00042960747231488277, 0.0004296074723148806, -8.450422373274219e-05, -8.450422373274045e-05]
# Operator(s) added to ansatz: [43]
#
# Screening operators with disjoint supports...
# 2 viable candidates: [57, 58]
# Operator(s) added to ansatz: [43, 57]
#
# Screening operators with disjoint supports...
# None found.
#
# Initial energy: -1.9802044582444092
# Optimizing energy with indices [72, 28, 41, 59, 22, 78, 43, 57]...
# Starting point: [-0.3381350276214911, -0.143337723308155, 0.2672316194959174, 0.26723161949591767, -0.08769242118306336, -0.0748281195111068, 0.0, 0.0]
# Optimization terminated successfully.
#          Current function value: -1.991765
#          Iterations: 9
#          Function evaluations: 10
#          Gradient evaluations: 10
#
# Current energy: -1.9917648850276626
# (change of -0.011560426783253419)
# Current ansatz: [72, 28, 41, 59, 22, 78, 43, 57]
#
# *** ADAPT-VQE Iteration 5 ***
#
# Creating list of up to 90 operators ordered by gradient magnitude...
#
# Non-Zero Gradients (tolerance E-8):
# Operator 1: 8.374859265603167e-05
# Operator 4: -8.374859265589346e-05
# Operator 7: 0.002388299731950284
# Operator 9: -0.0023882997319503896
# Operator 12: -0.0009632019803041923
# Operator 16: -0.01116902994826037
# Operator 17: -0.003053442413359042
# Operator 20: 0.011169029948260393
# Operator 21: 0.003053442413359031
# Operator 30: -0.0030747875641906133
# Operator 31: -0.002583310022945794
# Operator 34: 0.040994679758105196
# Operator 35: 0.0002622273610755005
# Operator 36: -0.0012953759064393451
# Operator 37: 0.002612502970016993
# Operator 38: -0.0001300220552645369
# Operator 42: -0.0009861091590734833
# Operator 44: -0.00982438960514082
# Operator 49: 0.01186503017141083
# Operator 50: -0.0030747875641906255
# Operator 51: 0.003074787564190623
# Operator 52: 0.0025833100229457583
# Operator 58: -0.009824389605140815
# Operator 60: -0.0009861091590734842
# Operator 63: 0.0026125029700169514
# Operator 64: -0.00013002205526458028
# Operator 65: 0.04099467975810519
# Operator 66: 0.0002622273610755378
# Operator 67: -0.0012953759064392514
# Operator 70: -0.011865030171410869
# Operator 71: -0.0030747875641906116
# Operator 80: 0.003053442413359026
# Operator 81: -0.0033803116598990104
# Operator 84: -0.003053442413359046
# Operator 85: 0.0033803116598989822
# Operator 88: -0.001578442878101001
# Total gradient norm: 0.06504223376439298
#
# Convergence condition achieved!
#
# Final Energy: -1.9917648850276626
# Error: 0.004385440491146753
# (in % of chemical accuracy: 275.191%)
# Iterations completed: 4
# Ansatz indices: [72, 28, 41, 59, 22, 78, 43, 57]
# Coefficiens: [-0.3251524305287548, -0.1417510026600473, 0.22207685265346044, 0.22207685265346078, -0.12610824866974532, -0.10748930129152007, -0.12249096668338713, -0.12249096668338721]
# Evolution of ansatz indices:  [[72, 28], [72, 28, 41, 59], [72, 28, 41, 59, 22, 78], [72, 28, 41, 59, 22, 78, 43, 57]]
# Final operators in the ansatz:  [-0.125j [X2 X3 X4 Y5] +
# -0.125j [X2 X3 Y4 X5] +
# 0.125j [X2 Y3 X4 X5] +
# -0.125j [X2 Y3 Y4 Y5] +
# 0.125j [Y2 X3 X4 X5] +
# -0.125j [Y2 X3 Y4 Y5] +
# 0.125j [Y2 Y3 X4 Y5] +
# 0.125j [Y2 Y3 Y4 X5], -0.125j [X0 X1 X6 Y7] +
# -0.125j [X0 X1 Y6 X7] +
# 0.125j [X0 Y1 X6 X7] +
# -0.125j [X0 Y1 Y6 Y7] +
# 0.125j [Y0 X1 X6 X7] +
# -0.125j [Y0 X1 Y6 Y7] +
# 0.125j [Y0 Y1 X6 Y7] +
# 0.125j [Y0 Y1 Y6 X7], -0.125j [X0 X3 X4 Y7] +
# -0.125j [X0 X3 Y4 X7] +
# 0.125j [X0 Y3 X4 X7] +
# -0.125j [X0 Y3 Y4 Y7] +
# 0.125j [Y0 X3 X4 X7] +
# -0.125j [Y0 X3 Y4 Y7] +
# 0.125j [Y0 Y3 X4 Y7] +
# 0.125j [Y0 Y3 Y4 X7], -0.125j [X1 X2 X5 Y6] +
# -0.125j [X1 X2 Y5 X6] +
# 0.125j [X1 Y2 X5 X6] +
# -0.125j [X1 Y2 Y5 Y6] +
# 0.125j [Y1 X2 X5 X6] +
# -0.125j [Y1 X2 Y5 Y6] +
# 0.125j [Y1 Y2 X5 Y6] +
# 0.125j [Y1 Y2 Y5 X6], -0.125j [X0 X1 X4 Y5] +
# -0.125j [X0 X1 Y4 X5] +
# 0.125j [X0 Y1 X4 X5] +
# -0.125j [X0 Y1 Y4 Y5] +
# 0.125j [Y0 X1 X4 X5] +
# -0.125j [Y0 X1 Y4 Y5] +
# 0.125j [Y0 Y1 X4 Y5] +
# 0.125j [Y0 Y1 Y4 X5], -0.125j [X2 X3 X6 Y7] +
# -0.125j [X2 X3 Y6 X7] +
# 0.125j [X2 Y3 X6 X7] +
# -0.125j [X2 Y3 Y6 Y7] +
# 0.125j [Y2 X3 X6 X7] +
# -0.125j [Y2 X3 Y6 Y7] +
# 0.125j [Y2 Y3 X6 Y7] +
# 0.125j [Y2 Y3 Y6 X7], -0.125j [X0 X3 X5 Y6] +
# -0.125j [X0 X3 Y5 X6] +
# 0.125j [X0 Y3 X5 X6] +
# -0.125j [X0 Y3 Y5 Y6] +
# 0.125j [Y0 X3 X5 X6] +
# -0.125j [Y0 X3 Y5 Y6] +
# 0.125j [Y0 Y3 X5 Y6] +
# 0.125j [Y0 Y3 Y5 X6], -0.125j [X1 X2 X4 Y7] +
# -0.125j [X1 X2 Y4 X7] +
# 0.125j [X1 Y2 X4 X7] +
# -0.125j [X1 Y2 Y4 Y7] +
# 0.125j [Y1 X2 X4 X7] +
# -0.125j [Y1 X2 Y4 Y7] +
# 0.125j [Y1 Y2 X4 Y7] +
# 0.125j [Y1 Y2 Y4 X7]]
# Evolution of ansatz coefficients:  [[-0.30688337459482085, -0.11344101184957128], [-0.37342137573909673, -0.15690533179199273, 0.2718258895584216, 0.27182588955842196], [-0.3381350276214911, -0.143337723308155, 0.2672316194959174, 0.26723161949591767, -0.08769242118306336, -0.0748281195111068], [-0.3251524305287548, -0.1417510026600473, 0.22207685265346044, 0.22207685265346078, -0.12610824866974532, -0.10748930129152007, -0.12249096668338713, -0.12249096668338721]]
# Function evaluations throughout the iterations: [[8], [9], [10], [10]]
# Gradient evaluations throughout the iterations: [[16], [36], [60], [80]]
# Optimizer iterations throughout the iterations: [[7], [8], [9], [9]]
# Final ansatz circuit:
#                                                                 »
# q_7: ──────────────────────────────────────────────────────────»
#                                                                »
# q_6: ──────────────────────────────────────────────────────────»
#                ┌───┐      ┌───┐                                »
# q_5: ──■───────┤ X ├──────┤ H ├────────────────────────────────»
#      ┌─┴─┐┌───┐└─┬─┘      ├───┤                           ┌───┐»
# q_4: ┤ X ├┤ X ├──┼────────┤ H ├───────────────────────────┤ X ├»
#      └───┘└───┘  │  ┌─────┴───┴─────┐     ┌──────────────┐└─┬─┘»
# q_3: ──■─────────■──┤ Ry(-0.081288) ├──■──┤ Ry(0.081288) ├──■──»
#      ┌─┴─┐┌───┐┌───┐└───────────────┘┌─┴─┐└──────────────┘     »
# q_2: ┤ X ├┤ X ├┤ H ├─────────────────┤ X ├─────────────────────»
#      └───┘└───┘└───┘                 └───┘                     »
# q_1: ──────────────────────────────────────────────────────────»
#                                                                »
# q_0: ──────────────────────────────────────────────────────────»
#                                                                »
# «                                                                      »
# «q_7: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_6: ─────────────────────────────────────────────────────────────────»
# «                                           ┌───┐   ┌─────────┐        »
# «q_5: ──────────────────────────────────────┤ X ├───┤ Rz(π/2) ├────────»
# «                                           └─┬─┘   └─────────┘        »
# «q_4: ────────────────────────────────────────┼────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌───────────────┐     »
# «q_3: ┤ Ry(-0.081288) ├──■──┤ Ry(0.081288) ├──■──┤ Ry(-0.081288) ├──■──»
# «     └───────────────┘┌─┴─┐└──────────────┘     └───────────────┘┌─┴─┐»
# «q_2: ─────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                      └───┘                                      └───┘»
# «q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                     »
# «q_7: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_6: ────────────────────────────────────────────────────────────────»
# «                                                                ┌───┐»
# «q_5: ───────────────────────────────────────────────────────────┤ X ├»
# «                     ┌───┐      ┌───┐      ┌───┐                └─┬─┘»
# «q_4: ────────────────┤ X ├──────┤ H ├──────┤ X ├──────────────────┼──»
# «     ┌──────────────┐└─┬─┘┌─────┴───┴─────┐└───┘┌──────────────┐  │  »
# «q_3: ┤ Ry(0.081288) ├──■──┤ Ry(-0.081288) ├──■──┤ Ry(0.081288) ├──■──»
# «     └──────────────┘     └───────────────┘┌─┴─┐└────┬───┬─────┘┌───┐»
# «q_2: ──────────────────────────────────────┤ X ├─────┤ H ├──────┤ X ├»
# «                                           └───┘     └───┘      └───┘»
# «q_1: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_0: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «                                  ░           ┌───┐      ┌───┐           »
# «q_7: ─────────────────────────────░───■───────┤ X ├──────┤ H ├───────────»
# «                                  ░ ┌─┴─┐┌───┐└─┬─┘      ├───┤           »
# «q_6: ─────────────────────────────░─┤ X ├┤ X ├──┼────────┤ H ├───────────»
# «     ┌─────────┐ ┌─────────┐      ░ └───┘└───┘  │        └───┘           »
# «q_5: ┤ Rz(π/2) ├─┤ Ry(π/2) ├──■───░─────────────┼────────────────────────»
# «     └─────────┘ └─────────┘┌─┴─┐ ░             │                        »
# «q_4: ───────────────────────┤ X ├─░─────────────┼────────────────────────»
# «     ┌──────────┐           └───┘ ░             │                        »
# «q_3: ┤ Rz(-π/2) ├─────■───────────░─────────────┼────────────────────────»
# «     └──────────┘   ┌─┴─┐         ░             │                        »
# «q_2: ───────────────┤ X ├─────────░─────────────┼────────────────────────»
# «                    └───┘         ░             │  ┌───────────────┐     »
# «q_1: ─────────────────────────────░───■─────────■──┤ Ry(-0.035438) ├──■──»
# «                                  ░ ┌─┴─┐┌───┐┌───┐└───────────────┘┌─┴─┐»
# «q_0: ─────────────────────────────░─┤ X ├┤ X ├┤ H ├─────────────────┤ X ├»
# «                                  ░ └───┘└───┘└───┘                 └───┘»
# «                                                                ┌───┐»
# «q_7: ───────────────────────────────────────────────────────────┤ X ├»
# «                     ┌───┐                                      └─┬─┘»
# «q_6: ────────────────┤ X ├────────────────────────────────────────┼──»
# «                     └─┬─┘                                        │  »
# «q_5: ──────────────────┼──────────────────────────────────────────┼──»
# «                       │                                          │  »
# «q_4: ──────────────────┼──────────────────────────────────────────┼──»
# «                       │                                          │  »
# «q_3: ──────────────────┼──────────────────────────────────────────┼──»
# «                       │                                          │  »
# «q_2: ──────────────────┼──────────────────────────────────────────┼──»
# «     ┌──────────────┐  │  ┌───────────────┐     ┌──────────────┐  │  »
# «q_1: ┤ Ry(0.035438) ├──■──┤ Ry(-0.035438) ├──■──┤ Ry(0.035438) ├──■──»
# «     └──────────────┘     └───────────────┘┌─┴─┐└──────────────┘     »
# «q_0: ──────────────────────────────────────┤ X ├─────────────────────»
# «                                           └───┘                     »
# «        ┌─────────┐                                                   »
# «q_7: ───┤ Rz(π/2) ├───────────────────────────────────────────────────»
# «        └─────────┘                        ┌───┐      ┌───┐      ┌───┐»
# «q_6: ──────────────────────────────────────┤ X ├──────┤ H ├──────┤ X ├»
# «                                           └─┬─┘      └───┘      └───┘»
# «q_5: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_4: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_3: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_2: ────────────────────────────────────────┼────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌───────────────┐     »
# «q_1: ┤ Ry(-0.035438) ├──■──┤ Ry(0.035438) ├──■──┤ Ry(-0.035438) ├──■──»
# «     └───────────────┘┌─┴─┐└──────────────┘     └───────────────┘┌─┴─┐»
# «q_0: ─────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                      └───┘                                      └───┘»
# «                     ┌───┐┌─────────┐ ┌─────────┐      ░           ┌───┐»
# «q_7: ────────────────┤ X ├┤ Rz(π/2) ├─┤ Ry(π/2) ├──■───░───■───────┤ X ├»
# «                     └─┬─┘└─────────┘ └─────────┘┌─┴─┐ ░   │       └─┬─┘»
# «q_6: ──────────────────┼─────────────────────────┤ X ├─░───┼─────────┼──»
# «                       │                         └───┘ ░   │         │  »
# «q_5: ──────────────────┼───────────────────────────────░───┼─────────┼──»
# «                       │                               ░ ┌─┴─┐┌───┐  │  »
# «q_4: ──────────────────┼───────────────────────────────░─┤ X ├┤ X ├──┼──»
# «                       │                               ░ └───┘└───┘  │  »
# «q_3: ──────────────────┼───────────────────────────────░───■─────────■──»
# «                       │                               ░   │            »
# «q_2: ──────────────────┼───────────────────────────────░───┼────────────»
# «     ┌──────────────┐  │  ┌──────────┐                 ░   │            »
# «q_1: ┤ Ry(0.035438) ├──■──┤ Rz(-π/2) ├─────■───────────░───┼────────────»
# «     └────┬───┬─────┘┌───┐└──────────┘   ┌─┴─┐         ░ ┌─┴─┐┌───┐┌───┐»
# «q_0: ─────┤ H ├──────┤ X ├───────────────┤ X ├─────────░─┤ X ├┤ X ├┤ H ├»
# «          └───┘      └───┘               └───┘         ░ └───┘└───┘└───┘»
# «          ┌───┐                                                      »
# «q_7: ─────┤ H ├──────────────────────────────────────────────────────»
# «          └───┘                                                      »
# «q_6: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_5: ────────────────────────────────────────────────────────────────»
# «          ┌───┐                            ┌───┐                     »
# «q_4: ─────┤ H ├────────────────────────────┤ X ├─────────────────────»
# «     ┌────┴───┴─────┐     ┌───────────────┐└─┬─┘┌──────────────┐     »
# «q_3: ┤ Ry(0.055519) ├──■──┤ Ry(-0.055519) ├──■──┤ Ry(0.055519) ├──■──»
# «     └──────────────┘  │  └───────────────┘     └──────────────┘  │  »
# «q_2: ──────────────────┼──────────────────────────────────────────┼──»
# «                       │                                          │  »
# «q_1: ──────────────────┼──────────────────────────────────────────┼──»
# «                     ┌─┴─┐                                      ┌─┴─┐»
# «q_0: ────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                     └───┘                                      └───┘»
# «                      ┌───┐  ┌─────────┐                              »
# «q_7: ─────────────────┤ X ├──┤ Rz(π/2) ├──────────────────────────────»
# «                      └─┬─┘  └─────────┘                              »
# «q_6: ───────────────────┼─────────────────────────────────────────────»
# «                        │                                             »
# «q_5: ───────────────────┼─────────────────────────────────────────────»
# «                        │                                        ┌───┐»
# «q_4: ───────────────────┼────────────────────────────────────────┤ X ├»
# «     ┌───────────────┐  │  ┌──────────────┐     ┌───────────────┐└─┬─┘»
# «q_3: ┤ Ry(-0.055519) ├──■──┤ Ry(0.055519) ├──■──┤ Ry(-0.055519) ├──■──»
# «     └───────────────┘     └──────────────┘  │  └───────────────┘     »
# «q_2: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_1: ────────────────────────────────────────┼────────────────────────»
# «                                           ┌─┴─┐                      »
# «q_0: ──────────────────────────────────────┤ X ├──────────────────────»
# «                                           └───┘                      »
# «                                           ┌───┐┌─────────┐ ┌─────────┐     »
# «q_7: ──────────────────────────────────────┤ X ├┤ Rz(π/2) ├─┤ Ry(π/2) ├──■──»
# «                                           └─┬─┘└─────────┘ └─────────┘  │  »
# «q_6: ────────────────────────────────────────┼───────────────────────────┼──»
# «                                             │                           │  »
# «q_5: ────────────────────────────────────────┼───────────────────────────┼──»
# «          ┌───┐      ┌───┐                   │                         ┌─┴─┐»
# «q_4: ─────┤ H ├──────┤ X ├───────────────────┼─────────────────────────┤ X ├»
# «     ┌────┴───┴─────┐└───┘┌───────────────┐  │  ┌──────────┐           └───┘»
# «q_3: ┤ Ry(0.055519) ├──■──┤ Ry(-0.055519) ├──■──┤ Rz(-π/2) ├─────■──────────»
# «     └──────────────┘  │  └───────────────┘     └──────────┘     │          »
# «q_2: ──────────────────┼─────────────────────────────────────────┼──────────»
# «                       │                                         │          »
# «q_1: ──────────────────┼─────────────────────────────────────────┼──────────»
# «                     ┌─┴─┐      ┌───┐      ┌───┐               ┌─┴─┐        »
# «q_0: ────────────────┤ X ├──────┤ H ├──────┤ X ├───────────────┤ X ├────────»
# «                     └───┘      └───┘      └───┘               └───┘        »
# «      ░                                                           »
# «q_7: ─░───────────────────────────────────────────────────────────»
# «      ░           ┌───┐     ┌───┐                                 »
# «q_6: ─░───■───────┤ X ├─────┤ H ├─────────────────────────────────»
# «      ░ ┌─┴─┐┌───┐└─┬─┘     ├───┤                            ┌───┐»
# «q_5: ─░─┤ X ├┤ X ├──┼───────┤ H ├────────────────────────────┤ X ├»
# «      ░ └───┘└───┘  │       └───┘                            └─┬─┘»
# «q_4: ─░─────────────┼──────────────────────────────────────────┼──»
# «      ░             │                                          │  »
# «q_3: ─░─────────────┼──────────────────────────────────────────┼──»
# «      ░             │  ┌──────────────┐     ┌───────────────┐  │  »
# «q_2: ─░───■─────────■──┤ Ry(0.055519) ├──■──┤ Ry(-0.055519) ├──■──»
# «      ░ ┌─┴─┐┌───┐┌───┐└──────────────┘┌─┴─┐└───────────────┘     »
# «q_1: ─░─┤ X ├┤ X ├┤ H ├────────────────┤ X ├──────────────────────»
# «      ░ └───┘└───┘└───┘                └───┘                      »
# «q_0: ─░───────────────────────────────────────────────────────────»
# «      ░                                                           »
# «                                                                     »
# «q_7: ────────────────────────────────────────────────────────────────»
# «                                           ┌───┐  ┌─────────┐        »
# «q_6: ──────────────────────────────────────┤ X ├──┤ Rz(π/2) ├────────»
# «                                           └─┬─┘  └─────────┘        »
# «q_5: ────────────────────────────────────────┼───────────────────────»
# «                                             │                       »
# «q_4: ────────────────────────────────────────┼───────────────────────»
# «                                             │                       »
# «q_3: ────────────────────────────────────────┼───────────────────────»
# «     ┌──────────────┐     ┌───────────────┐  │  ┌──────────────┐     »
# «q_2: ┤ Ry(0.055519) ├──■──┤ Ry(-0.055519) ├──■──┤ Ry(0.055519) ├──■──»
# «     └──────────────┘┌─┴─┐└───────────────┘     └──────────────┘┌─┴─┐»
# «q_1: ────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                     └───┘                                      └───┘»
# «q_0: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «                                                                      »
# «q_7: ─────────────────────────────────────────────────────────────────»
# «                                                                 ┌───┐»
# «q_6: ────────────────────────────────────────────────────────────┤ X ├»
# «                      ┌───┐     ┌───┐      ┌───┐                 └─┬─┘»
# «q_5: ─────────────────┤ X ├─────┤ H ├──────┤ X ├───────────────────┼──»
# «                      └─┬─┘     └───┘      └───┘                   │  »
# «q_4: ───────────────────┼──────────────────────────────────────────┼──»
# «                        │                                          │  »
# «q_3: ───────────────────┼──────────────────────────────────────────┼──»
# «     ┌───────────────┐  │  ┌──────────────┐     ┌───────────────┐  │  »
# «q_2: ┤ Ry(-0.055519) ├──■──┤ Ry(0.055519) ├──■──┤ Ry(-0.055519) ├──■──»
# «     └───────────────┘     └──────────────┘┌─┴─┐└─────┬───┬─────┘┌───┐»
# «q_1: ──────────────────────────────────────┤ X ├──────┤ H ├──────┤ X ├»
# «                                           └───┘      └───┘      └───┘»
# «q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «                                  ░           ┌───┐      ┌───┐           »
# «q_7: ─────────────────────────────░───■───────┤ X ├──────┤ H ├───────────»
# «     ┌─────────┐ ┌─────────┐      ░ ┌─┴─┐┌───┐└─┬─┘      ├───┤           »
# «q_6: ┤ Rz(π/2) ├─┤ Ry(π/2) ├──■───░─┤ X ├┤ X ├──┼────────┤ H ├───────────»
# «     └─────────┘ └─────────┘┌─┴─┐ ░ └───┘└───┘  │        └───┘           »
# «q_5: ───────────────────────┤ X ├─░─────────────┼────────────────────────»
# «                            └───┘ ░             │                        »
# «q_4: ─────────────────────────────░─────────────┼────────────────────────»
# «                                  ░             │  ┌───────────────┐     »
# «q_3: ─────────────────────────────░───■─────────■──┤ Ry(-0.031527) ├──■──»
# «     ┌──────────┐                 ░ ┌─┴─┐┌───┐┌───┐└───────────────┘┌─┴─┐»
# «q_2: ┤ Rz(-π/2) ├─────■───────────░─┤ X ├┤ X ├┤ H ├─────────────────┤ X ├»
# «     └──────────┘   ┌─┴─┐         ░ └───┘└───┘└───┘                 └───┘»
# «q_1: ───────────────┤ X ├─────────░──────────────────────────────────────»
# «                    └───┘         ░                                      »
# «q_0: ─────────────────────────────░──────────────────────────────────────»
# «                                  ░                                      »
# «                                                                ┌───┐»
# «q_7: ───────────────────────────────────────────────────────────┤ X ├»
# «                     ┌───┐                                      └─┬─┘»
# «q_6: ────────────────┤ X ├────────────────────────────────────────┼──»
# «                     └─┬─┘                                        │  »
# «q_5: ──────────────────┼──────────────────────────────────────────┼──»
# «                       │                                          │  »
# «q_4: ──────────────────┼──────────────────────────────────────────┼──»
# «     ┌──────────────┐  │  ┌───────────────┐     ┌──────────────┐  │  »
# «q_3: ┤ Ry(0.031527) ├──■──┤ Ry(-0.031527) ├──■──┤ Ry(0.031527) ├──■──»
# «     └──────────────┘     └───────────────┘┌─┴─┐└──────────────┘     »
# «q_2: ──────────────────────────────────────┤ X ├─────────────────────»
# «                                           └───┘                     »
# «q_1: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_0: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «        ┌─────────┐                                                   »
# «q_7: ───┤ Rz(π/2) ├───────────────────────────────────────────────────»
# «        └─────────┘                        ┌───┐      ┌───┐      ┌───┐»
# «q_6: ──────────────────────────────────────┤ X ├──────┤ H ├──────┤ X ├»
# «                                           └─┬─┘      └───┘      └───┘»
# «q_5: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_4: ────────────────────────────────────────┼────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌───────────────┐     »
# «q_3: ┤ Ry(-0.031527) ├──■──┤ Ry(0.031527) ├──■──┤ Ry(-0.031527) ├──■──»
# «     └───────────────┘┌─┴─┐└──────────────┘     └───────────────┘┌─┴─┐»
# «q_2: ─────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                      └───┘                                      └───┘»
# «q_1: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «                     ┌───┐┌─────────┐ ┌─────────┐      ░                »
# «q_7: ────────────────┤ X ├┤ Rz(π/2) ├─┤ Ry(π/2) ├──■───░────────────────»
# «                     └─┬─┘└─────────┘ └─────────┘┌─┴─┐ ░                »
# «q_6: ──────────────────┼─────────────────────────┤ X ├─░────────────────»
# «                       │                         └───┘ ░           ┌───┐»
# «q_5: ──────────────────┼───────────────────────────────░───■───────┤ X ├»
# «                       │                               ░ ┌─┴─┐┌───┐└─┬─┘»
# «q_4: ──────────────────┼───────────────────────────────░─┤ X ├┤ X ├──┼──»
# «     ┌──────────────┐  │  ┌──────────┐                 ░ └───┘└───┘  │  »
# «q_3: ┤ Ry(0.031527) ├──■──┤ Rz(-π/2) ├─────■───────────░─────────────┼──»
# «     └────┬───┬─────┘┌───┐└──────────┘   ┌─┴─┐         ░             │  »
# «q_2: ─────┤ H ├──────┤ X ├───────────────┤ X ├─────────░─────────────┼──»
# «          └───┘      └───┘               └───┘         ░             │  »
# «q_1: ──────────────────────────────────────────────────░───■─────────■──»
# «                                                       ░ ┌─┴─┐┌───┐┌───┐»
# «q_0: ──────────────────────────────────────────────────░─┤ X ├┤ X ├┤ H ├»
# «                                                       ░ └───┘└───┘└───┘»
# «                                                                      »
# «q_7: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_6: ─────────────────────────────────────────────────────────────────»
# «           ┌───┐                                                      »
# «q_5: ──────┤ H ├──────────────────────────────────────────────────────»
# «           ├───┤                           ┌───┐                      »
# «q_4: ──────┤ H ├───────────────────────────┤ X ├──────────────────────»
# «           └───┘                           └─┬─┘                      »
# «q_3: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_2: ────────────────────────────────────────┼────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌───────────────┐     »
# «q_1: ┤ Ry(-0.026872) ├──■──┤ Ry(0.026872) ├──■──┤ Ry(-0.026872) ├──■──»
# «     └───────────────┘┌─┴─┐└──────────────┘     └───────────────┘┌─┴─┐»
# «q_0: ─────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                      └───┘                                      └───┘»
# «                                                                     »
# «q_7: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «q_6: ────────────────────────────────────────────────────────────────»
# «                     ┌───┐   ┌─────────┐                             »
# «q_5: ────────────────┤ X ├───┤ Rz(π/2) ├─────────────────────────────»
# «                     └─┬─┘   └─────────┘                        ┌───┐»
# «q_4: ──────────────────┼────────────────────────────────────────┤ X ├»
# «                       │                                        └─┬─┘»
# «q_3: ──────────────────┼──────────────────────────────────────────┼──»
# «                       │                                          │  »
# «q_2: ──────────────────┼──────────────────────────────────────────┼──»
# «     ┌──────────────┐  │  ┌───────────────┐     ┌──────────────┐  │  »
# «q_1: ┤ Ry(0.026872) ├──■──┤ Ry(-0.026872) ├──■──┤ Ry(0.026872) ├──■──»
# «     └──────────────┘     └───────────────┘┌─┴─┐└──────────────┘     »
# «q_0: ──────────────────────────────────────┤ X ├─────────────────────»
# «                                           └───┘                     »
# «                                                                            »
# «q_7: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_6: ───────────────────────────────────────────────────────────────────────»
# «                                           ┌───┐┌─────────┐ ┌─────────┐     »
# «q_5: ──────────────────────────────────────┤ X ├┤ Rz(π/2) ├─┤ Ry(π/2) ├──■──»
# «           ┌───┐      ┌───┐                └─┬─┘└─────────┘ └─────────┘┌─┴─┐»
# «q_4: ──────┤ H ├──────┤ X ├──────────────────┼─────────────────────────┤ X ├»
# «           └───┘      └───┘                  │                         └───┘»
# «q_3: ────────────────────────────────────────┼──────────────────────────────»
# «                                             │                              »
# «q_2: ────────────────────────────────────────┼──────────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌──────────┐                »
# «q_1: ┤ Ry(-0.026872) ├──■──┤ Ry(0.026872) ├──■──┤ Rz(-π/2) ├─────■──────────»
# «     └───────────────┘┌─┴─┐└────┬───┬─────┘┌───┐└──────────┘   ┌─┴─┐        »
# «q_0: ─────────────────┤ X ├─────┤ H ├──────┤ X ├───────────────┤ X ├────────»
# «                      └───┘     └───┘      └───┘               └───┘        »
# «      ░           ┌───┐      ┌───┐                                »
# «q_7: ─░───■───────┤ X ├──────┤ H ├────────────────────────────────»
# «      ░   │       └─┬─┘      └───┘                                »
# «q_6: ─░───┼─────────┼─────────────────────────────────────────────»
# «      ░   │         │                                             »
# «q_5: ─░───┼─────────┼─────────────────────────────────────────────»
# «      ░ ┌─┴─┐┌───┐  │        ┌───┐                           ┌───┐»
# «q_4: ─░─┤ X ├┤ X ├──┼────────┤ H ├───────────────────────────┤ X ├»
# «      ░ └───┘└───┘  │        └───┘                           └─┬─┘»
# «q_3: ─░─────────────┼──────────────────────────────────────────┼──»
# «      ░             │  ┌───────────────┐     ┌──────────────┐  │  »
# «q_2: ─░───■─────────■──┤ Ry(-0.030623) ├──■──┤ Ry(0.030623) ├──■──»
# «      ░ ┌─┴─┐┌───┐┌───┐└───────────────┘┌─┴─┐└──────────────┘     »
# «q_1: ─░─┤ X ├┤ X ├┤ H ├─────────────────┤ X ├─────────────────────»
# «      ░ └───┘└───┘└───┘                 └───┘                     »
# «q_0: ─░───────────────────────────────────────────────────────────»
# «      ░                                                           »
# «                                           ┌───┐   ┌─────────┐        »
# «q_7: ──────────────────────────────────────┤ X ├───┤ Rz(π/2) ├────────»
# «                                           └─┬─┘   └─────────┘        »
# «q_6: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_5: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_4: ────────────────────────────────────────┼────────────────────────»
# «                                             │                        »
# «q_3: ────────────────────────────────────────┼────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌───────────────┐     »
# «q_2: ┤ Ry(-0.030623) ├──■──┤ Ry(0.030623) ├──■──┤ Ry(-0.030623) ├──■──»
# «     └───────────────┘┌─┴─┐└──────────────┘     └───────────────┘┌─┴─┐»
# «q_1: ─────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                      └───┘                                      └───┘»
# «q_0: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «                                                                ┌───┐»
# «q_7: ───────────────────────────────────────────────────────────┤ X ├»
# «                                                                └─┬─┘»
# «q_6: ─────────────────────────────────────────────────────────────┼──»
# «                                                                  │  »
# «q_5: ─────────────────────────────────────────────────────────────┼──»
# «                     ┌───┐      ┌───┐      ┌───┐                  │  »
# «q_4: ────────────────┤ X ├──────┤ H ├──────┤ X ├──────────────────┼──»
# «                     └─┬─┘      └───┘      └───┘                  │  »
# «q_3: ──────────────────┼──────────────────────────────────────────┼──»
# «     ┌──────────────┐  │  ┌───────────────┐     ┌──────────────┐  │  »
# «q_2: ┤ Ry(0.030623) ├──■──┤ Ry(-0.030623) ├──■──┤ Ry(0.030623) ├──■──»
# «     └──────────────┘     └───────────────┘┌─┴─┐└────┬───┬─────┘┌───┐»
# «q_1: ──────────────────────────────────────┤ X ├─────┤ H ├──────┤ X ├»
# «                                           └───┘     └───┘      └───┘»
# «q_0: ────────────────────────────────────────────────────────────────»
# «                                                                     »
# «     ┌─────────┐ ┌─────────┐      ░                                      »
# «q_7: ┤ Rz(π/2) ├─┤ Ry(π/2) ├──■───░──────────────────────────────────────»
# «     └─────────┘ └─────────┘  │   ░           ┌───┐      ┌───┐           »
# «q_6: ─────────────────────────┼───░───■───────┤ X ├──────┤ H ├───────────»
# «                              │   ░ ┌─┴─┐┌───┐└─┬─┘      ├───┤           »
# «q_5: ─────────────────────────┼───░─┤ X ├┤ X ├──┼────────┤ H ├───────────»
# «                            ┌─┴─┐ ░ └───┘└───┘  │        └───┘           »
# «q_4: ───────────────────────┤ X ├─░─────────────┼────────────────────────»
# «                            └───┘ ░             │  ┌───────────────┐     »
# «q_3: ─────────────────────────────░───■─────────■──┤ Ry(-0.030623) ├──■──»
# «     ┌──────────┐                 ░   │            └───────────────┘  │  »
# «q_2: ┤ Rz(-π/2) ├─────■───────────░───┼───────────────────────────────┼──»
# «     └──────────┘   ┌─┴─┐         ░   │                               │  »
# «q_1: ───────────────┤ X ├─────────░───┼───────────────────────────────┼──»
# «                    └───┘         ░ ┌─┴─┐┌───┐┌───┐                 ┌─┴─┐»
# «q_0: ─────────────────────────────░─┤ X ├┤ X ├┤ H ├─────────────────┤ X ├»
# «                                  ░ └───┘└───┘└───┘                 └───┘»
# «                                                                     »
# «q_7: ────────────────────────────────────────────────────────────────»
# «                                                                ┌───┐»
# «q_6: ───────────────────────────────────────────────────────────┤ X ├»
# «                     ┌───┐                                      └─┬─┘»
# «q_5: ────────────────┤ X ├────────────────────────────────────────┼──»
# «                     └─┬─┘                                        │  »
# «q_4: ──────────────────┼──────────────────────────────────────────┼──»
# «     ┌──────────────┐  │  ┌───────────────┐     ┌──────────────┐  │  »
# «q_3: ┤ Ry(0.030623) ├──■──┤ Ry(-0.030623) ├──■──┤ Ry(0.030623) ├──■──»
# «     └──────────────┘     └───────────────┘  │  └──────────────┘     »
# «q_2: ────────────────────────────────────────┼───────────────────────»
# «                                             │                       »
# «q_1: ────────────────────────────────────────┼───────────────────────»
# «                                           ┌─┴─┐                     »
# «q_0: ──────────────────────────────────────┤ X ├─────────────────────»
# «                                           └───┘                     »
# «                                                                      »
# «q_7: ─────────────────────────────────────────────────────────────────»
# «        ┌─────────┐                                                   »
# «q_6: ───┤ Rz(π/2) ├───────────────────────────────────────────────────»
# «        └─────────┘                        ┌───┐      ┌───┐      ┌───┐»
# «q_5: ──────────────────────────────────────┤ X ├──────┤ H ├──────┤ X ├»
# «                                           └─┬─┘      └───┘      └───┘»
# «q_4: ────────────────────────────────────────┼────────────────────────»
# «     ┌───────────────┐     ┌──────────────┐  │  ┌───────────────┐     »
# «q_3: ┤ Ry(-0.030623) ├──■──┤ Ry(0.030623) ├──■──┤ Ry(-0.030623) ├──■──»
# «     └───────────────┘  │  └──────────────┘     └───────────────┘  │  »
# «q_2: ───────────────────┼──────────────────────────────────────────┼──»
# «                        │                                          │  »
# «q_1: ───────────────────┼──────────────────────────────────────────┼──»
# «                      ┌─┴─┐                                      ┌─┴─┐»
# «q_0: ─────────────────┤ X ├──────────────────────────────────────┤ X ├»
# «                      └───┘                                      └───┘»
# «                                                       ░
# «q_7: ──────────────────────────────────────────────────░─
# «                     ┌───┐┌─────────┐ ┌─────────┐      ░
# «q_6: ────────────────┤ X ├┤ Rz(π/2) ├─┤ Ry(π/2) ├──■───░─
# «                     └─┬─┘└─────────┘ └─────────┘┌─┴─┐ ░
# «q_5: ──────────────────┼─────────────────────────┤ X ├─░─
# «                       │                         └───┘ ░
# «q_4: ──────────────────┼───────────────────────────────░─
# «     ┌──────────────┐  │  ┌──────────┐                 ░
# «q_3: ┤ Ry(0.030623) ├──■──┤ Rz(-π/2) ├─────■───────────░─
# «     └──────────────┘     └──────────┘     │           ░
# «q_2: ──────────────────────────────────────┼───────────░─
# «                                           │           ░
# «q_1: ──────────────────────────────────────┼───────────░─
# «          ┌───┐      ┌───┐               ┌─┴─┐         ░
# «q_0: ─────┤ H ├──────┤ X ├───────────────┤ X ├─────────░─
# «          └───┘      └───┘               └───┘         ░
# Evolution of ansatz CNOT counts:  [0, 26, 52, 78, 104]
# Evolution of ansatz CNOT depths:  [0, 11, 22, 33, 44]
